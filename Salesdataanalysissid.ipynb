# %% [markdown]
# import pandas as pd: Imports the Pandas library, which is essential for working with data in Python. It provides tools for data manipulation and analysis using DataFrames.
# import matplotlib.pyplot as plt: Imports the Pyplot module from the Matplotlib library. This module provides a MATLAB-like interface for creating static, interactive, and animated visualizations in Python.
# import seaborn as sns: Imports the Seaborn library, which is built on top of Matplotlib and provides a high-level interface for creating attractive and informative statistical graphics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Assuming 'superstore_sales.xlsx' is the actual filename
file_path = 'superstore_sales.xlsx'  # Define the file path
df = pd.read_excel(file_path)

# %% [markdown]
# Showing top 5 entries

# %%
df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %% [markdown]
# Showing bottom 5 entries

# %%
df.tail()
# Out:
#              order_id order_date  ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51286    MO-2014-2560 2014-12-31 2015-01-05  Standard Class         Liz Preis
# 51287  MX-2014-110527 2014-12-31 2015-01-02    Second Class  Charlotte Melton
# 51288  MX-2014-114783 2014-12-31 2015-01-06  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720 2014-12-31 2015-01-04  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %% [markdown]
# It seems like you're trying to check the shape of your DataFrame df. That's a good way to get a quick overview of how much data you're working with.

# %%
df.shape
# Out:
# (51290, 21)

# %% [markdown]
# You got it! Running df.info() is a great way to get a summary of your DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
# ...

# %% [markdown]
# It will tell about the data types

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %% [markdown]
# When you run df.describe(), you'll get the following statistics for each numerical column:
#
# count: Number of non-missing values.
#
#
# mean: The average value.
#
# std: Standard deviation, a measure of how spread out the data is.
#
# min: The minimum value.
#
# 25%: The first quartile (25th percentile).
#
# 50%: The median (50th percentile).
#
# 75%: The third quartile (75th percentile).
#
# max: The maximum value.

# %%
df.describe()
# Out:
#                           order_date                      ship_date  \
# count                          51290                          51290
# mean   2013-05-11 21:26:49.155780864  2013-05-15 20:42:42.745174528
# min              2011-01-01 00:00:00            2011-01-03 00:00:00
# 25%              2012-06-19 00:00:00            2012-06-23 00:00:00
# 50%              2013-07-08 00:00:00            2013-07-12 00:00:00
# 75%              2014-05-22 00:00:00            2014-05-26 00:00:00
# max              2014-12-31 00:00:00            2015-01-07 00:00:00
# std                              NaN                            NaN
#
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# ...

# %% [markdown]
# That's a smart move! df.isnull().sum() is the perfect way to check for missing values in your DataFrame.

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# order_id          25035
# order_date         1430
# ship_date          1464
# ship_mode             4
# customer_name       795
# segment               3
# state              1094
# country             147
# market                7
# region               13
# product_id        10292
# category              3
# sub_category         17
# product_name       3788
# sales             27200
# quantity             14
# discount             29
# profit            28234
# shipping_cost     17095
# order_priority        4
# year                  4
# dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %% [markdown]
# Great! Using df['order_date'].min() will give you the earliest (minimum) order date in your dataset.

# %%
df['order_date'].min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %% [markdown]
# Perfect! df['order_date'].max() will give you the most recent (maximum) order date in your dataset.

# %%
df['order_date'].max()
# Out:
# Timestamp('2014-12-31 00:00:00')

# %% [markdown]
# That's a great way to get a quick overview of the distribution of customer segments in your data!

# %%
df['segment'].value_counts()
# Out:
# segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: count, dtype: int64

# %% [markdown]
# Excellent! That's a very useful step. By creating a 'month_year' column, you're extracting the month and year information from your 'order_date' column, which will make it easier to analyze trends over time.
#
# Explanation:
#
# df['order_date'].dt.strftime('%Y-%m'):
#
# df['order_date'] selects the 'order_date' column.
# .dt accesses datetime properties and methods.
# .strftime('%Y-%m') formats the datetime object into a string with the year ('%Y') followed by a hyphen and the month ('%m').
# df['month_year'] = ...: This assigns the resulting formatted strings to a new column called 'month_year' in your DataFrame.

# %%
df['month_year'] = df['order_date'].dt.strftime('%Y-%m')

# %%
df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %% [markdown]
# Great job! You've successfully calculated the total sales for each month and year and stored it in the df_trend DataFrame.
#
# Here's a breakdown of what you did:
#
# df.groupby('month_year')['sales']: This groups your original DataFrame df by the 'month_year' column and selects the 'sales' column for aggregation.
#
# .sum(): This calculates the sum of sales for each month-year group.
#
# .reset_index(): This converts the grouped result (which has a 'month_year' index) into a regular DataFrame with 'month_year' and 'sales' as columns.

# %%
df_trend=df.groupby('month_year')['sales'].sum().reset_index()

# %%
plt.figure(figsize=(15, 6))
plt.plot(df_trend['month_year'], df_trend['sales'], color='red')
plt.xlabel('Month-Year')
plt.ylabel('Sales')
plt.title('Sales Trend')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# You got it! Running df['product_name'] will select the 'product_name' column from your DataFrame and display its contents.
#
# What you'll see:
#
# A Series (a single column of data) containing all the product names in your dataset.

# %%
df['product_name']
# Out:
# 0                                    Tenex Lockers, Blue
# 1                               Acme Trimmer, High Speed
# 2                                Tenex Box, Single Width
# 3                            Enermax Note Cards, Premium
# 4                             Eldon Light Bulb, Duo Pack
#                               ...
# 51285    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# 51286            Wilson Jones Hole Reinforcements, Clear
# 51287             Hon Color Coded Labels, 5000 Label Set
# 51288             Hon Legal Exhibit Labels, Alphabetical
# 51289                                Bagged Rubber Bands
# Name: product_name, Length: 51290, dtype: object

# %% [markdown]
# Excellent work! You've successfully created a DataFrame prod_sales that shows the total sales for each product, sorted from highest to lowest.
#
# Here's a breakdown of your code:
#
# df.groupby('product_name')['sales']: This groups your DataFrame df by the 'product_name' column and selects the 'sales' column for aggregation.
#
# .sum(): This calculates the total sales for each product group.
#
# .sort_values(ascending=False): This sorts the resulting Series (product names as index, total sales as values) in descending order, so the highest-selling products appear first.
#
# pd.DataFrame(...): This creates a DataFrame from the sorted Series, making it easier to view and manipulate.

# %%
prod_sales=pd.DataFrame(df.groupby('product_name')['sales'].sum().sort_values(ascending=False))

# %%
prod_sales.head(10)
# Out:
#                                                          sales
# product_name
# Apple Smart Phone, Full Size                        86935.7786
# Cisco Smart Phone, Full Size                        76441.5306
# Motorola Smart Phone, Full Size                     73156.3030
# Nokia Smart Phone, Full Size                        71904.5555
# Canon imageCLASS 2200 Advanced Copier               61599.8240
# Hon Executive Leather Armchair, Adjustable          58193.4841
# Office Star Executive Leather Armchair, Adjustable  50661.6840
# Harbour Creations Executive Leather Armchair, A...  50121.5160
# Samsung Smart Phone, Cordless                       48653.4600
# Nokia Smart Phone, with Caller ID                   47877.7857

# %%
prod_sales.tail(10)
# Out:
#                                                     sales
# product_name
# Newell 308                                          8.400
# Stockwell Gold Paper Clips                          8.096
# 4009 Highlighters                                   8.040
# Xerox 1989                                          7.968
# Avery Hi-Liter Comfort Grip Fluorescent Highlig...  7.800
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set  7.700
# Grip Seal Envelopes                                 7.072
# Xerox 20                                            6.480
# Avery 5                                             5.760
# Eureka Disposable Bags for Sanitaire Vibra Groo...  1.624

# %%
most_sell_prod = pd.DataFrame(df.groupby('product_name')['quantity'])

# %%
most_sell_prod.head()
# Out:
#                                                    0  \
# 0  "While you Were Out" Message Book, One Form pe...
# 1           #10 Gummed Flap White Envelopes, 100/Box
# 2                      #10 Self-Seal White Envelopes
# 3         #10 White Business Envelopes,4 1/8 x 9 1/2
# 4            #10- 4 1/8" x 9 1/2" Recycled Envelopes
#
#                                                    1
# 0  43675    3
# 46985    2
# 47949    3
# Name: quantit...
# 1  17359    2
# 20306    4
# 22291    2
# 47008    3
# Na...
# 2  22292    1
# 28427    1
# 30020    6
# 44189    2
# Na...
# 3  5461     5
# 7200     5
# 16206    1
# 20649    8
# 32...
# 4  2666     2
# 3845     7
# 9103     2
# 16028    2
# 17...

# %% [markdown]
# You've got it! This is the perfect way to find the most sold products.
#
# Here's what you've done, step-by-step:
#
# df.groupby('product_name')['quantity']: You've grouped your DataFrame df by the 'product_name' column and selected the 'quantity' column for aggregation.
#
# .sum(): You've calculated the total quantity sold for each product group.
#
# .reset_index(): You've converted the result (which had 'product_name' as the index) into a regular DataFrame with 'product_name' and 'quantity' as columns.
#
# .sort_values(by='quantity', ascending=False): Finally, you've sorted the DataFrame by the 'quantity' column in descending order, so the products with the highest quantities sold are at the top.

# %%
most_sell_prod = df.groupby('product_name')['quantity'].sum().reset_index()
most_sell_prod.sort_values(by='quantity', ascending=False)
# Out:
#                                            product_name  quantity
# 3275                                            Staples       876
# 894                           Cardinal Index Tab, Clear       337
# 1210                      Eldon File Cart, Single Width       321
# 2840                     Rogers File Cart, Single Width       262
# 3070              Sanford Pencil Sharpener, Water Color       259
# ...                                                 ...       ...
# 2734                Penpower WorldCard Pro Card Scanner         1
# 797   Bush Saratoga Collection 5-Shelf Bookcase, Han...         1
# 679               Boston 1900 Electric Pencil Sharpener         1
# 3707                                           Xerox 20         1
# 1559  Global Enterprise Series Seating Low-Back Swiv...         1
#
# [3788 rows x 2 columns]

# %%
most_sell_prod[:10]
# Out:
#                                         product_name  quantity
# 0  "While you Were Out" Message Book, One Form pe...         8
# 1           #10 Gummed Flap White Envelopes, 100/Box        11
# 2                      #10 Self-Seal White Envelopes        10
# 3         #10 White Business Envelopes,4 1/8 x 9 1/2        32
# 4            #10- 4 1/8" x 9 1/2" Recycled Envelopes        37
# 5       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes        21
# 6  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...        13
# 7                 #6 3/4 Gummed Flap White Envelopes         9
# 8  1.7 Cubic Foot Compact "Cube" Office Refrigera...        14
# 9  1/4 Fold Party Design Invitations & White Enve...         7

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='product_name', y='quantity', data=most_sell_prod[:10], color='red')
plt.xticks(rotation=90)
plt.xlabel('Product Name')
plt.ylabel('Quantity')
plt.title('Top 10 Most Sold Products in Envelop')
plt.show()

# %% [markdown]
# custom_palette = ['green', 'blue', 'red', 'orange']: You've created a list of color names that you want to use for the different shipping modes.
#
# sns.countplot(data=df, x='ship_mode', palette=custom_palette):
#
# data=df specifies the DataFrame you're using.
# x='ship_mode' indicates that you want to count the occurrences of each shipping mode.
# palette=custom_palette applies your custom color palette to the bars in the plot.
# plt.show(): This displays the generated countplot.

# %%
custom_palette = ['green', 'blue', 'red', 'orange']  # Example colors
sns.countplot(data=df, x='ship_mode', palette=custom_palette)
plt.show()
# Out:
# <ipython-input-78-3afe857c4159>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='ship_mode', palette=custom_palette)

# %% [markdown]
# Great job! You've successfully calculated and sorted the profit for each category and sub-category combination.
#
# Here's a breakdown of what you did:
#
# df.groupby(['category', 'sub_category'])['profit'].sum(): You grouped your DataFrame df by both 'category' and 'sub_category' and then calculated the sum of profits for each group.
#
# .reset_index(): You converted the result (which had a multi-level index) into a regular DataFrame with 'category', 'sub_category', and 'profit' as columns.
#
# .sort_values(by='profit', ascending=False): You sorted the DataFrame by the 'profit' column in descending order, so the most profitable category/sub-category combinations appear at the top.
#
# print(category_profit): You printed the resulting DataFrame to display the sorted profits.

# %%
category_profit = df.groupby(['category', 'sub_category'])['profit'].sum().reset_index()
category_profit = category_profit.sort_values(by='profit', ascending=False)
print(category_profit)
# Out:
#            category sub_category        profit
# 14       Technology      Copiers  258567.54818
# 16       Technology       Phones  216717.00580
# 0         Furniture    Bookcases  161924.41950
# 1         Furniture       Chairs  141973.79750
# 4   Office Supplies   Appliances  141680.58940
# 13       Technology  Accessories  129626.30620
# 11  Office Supplies      Storage  108461.48980
# 6   Office Supplies      Binders   72449.84600
# 10  Office Supplies        Paper   59207.68270
# 15       Technology     Machines   58867.87300
# 5   Office Supplies          Art   57953.91090
# 2         Furniture  Furnishings   46967.42550
# 7   Office Supplies    Envelopes   29601.11630
# 12  Office Supplies     Supplies   22583.26310
# 9   Office Supplies       Labels   15010.51200
# 8   Office Supplies    Fasteners   11525.42410
# 3         Furniture       Tables  -64083.38870

# %% [markdown]
# That's an excellent way to visualize the profit by sub-category and category! You've created a clear and informative bar chart.
#
# Here's a breakdown of your code:
#
# plt.figure(figsize=(10, 6)): You set the figure size to make the plot wider for better readability.
#
# sns.barplot(x='sub_category', y='profit', hue='category', data=category_profit, palette='viridis'):
#
# x='sub_category' sets the sub-categories on the x-axis.
# y='profit' sets the profit values on the y-axis.
# hue='category' creates different colored bars for each category within each sub-category.
# data=category_profit specifies the DataFrame to use for plotting.
# palette='viridis' applies the 'viridis' color palette for a visually appealing look.
# plt.xticks(rotation=90): You rotate the x-axis labels by 90 degrees to prevent them from overlapping.
#
# plt.xlabel('Sub-Category') and plt.ylabel('Profit'): You set clear labels for the axes.
#
# plt.title('Profit by Sub-Category'): You add a descriptive title to the plot.
#
# plt.show(): You display the generated bar chart.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='sub_category', y='profit', hue='category', data=category_profit, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Sub-Category')
plt.ylabel('Profit')
plt.title('Profit by Sub-Category')
plt.show()
